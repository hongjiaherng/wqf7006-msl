# %% [markdown]
# Locally

# %%
# Locally
from wqf7006_msl.demo import my_demo_func

my_demo_func()
# Out:
# This is a demo function.

# %% [markdown]
# On Google Colab

# %%
# On Google Colab
# Mount Google Drive if running in Google Colab
try:
    import os

    from google.colab import drive

    drive.mount("/content/drive")
    print("Session is running on Google Colab.")
    print(f"Current working directory: {os.getcwd()}")
    os.chdir("/content/drive/MyDrive/wqf7006-msl")
    print(f"Current working directory (After): {os.getcwd()}")
except ImportError:
    print("Session is not running on Google Colab.")
    print(f"Current working directory: {os.getcwd()}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Session is running on Google Colab.
# Current working directory: /content
# Current working directory (After): /content/drive/.shortcut-targets-by-id/160DAGPJ5MewKabZa75O5JOkJI4TDm_Qn/wqf7006-msl
